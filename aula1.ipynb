# %% [markdown]
# <a href="https://colab.research.google.com/github/leanoguerreiro/deeplearning/blob/main/aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab import files

uploaded = files.upload()
img_path = list(uploaded.keys())[0]
img = cv2.imread(img_path)


print(f'Dimenssões: {img.shape}')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.title('Imagem RBG')
plt.axis('off')
plt.show()
# Out:
#      <input type="file" id="files-c6f8287d-df8f-4188-842d-0f3d996f3adb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c6f8287d-df8f-4188-842d-0f3d996f3adb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(f'Dimenssões: {img_gray.shape}')
plt.imshow(img_gray, cmap='gray')
plt.title('Imagem gray')
plt.axis('off')
plt.show()
# Out:
# Dimenssões: (5978, 3985)

# %%
hist = cv2.calcHist([img_gray], [0], None, [256], [0,256])
plt.plot(hist)
plt.title('Histograma da Imagem em Escala de Cinza')
plt.xlabel('Nivel de Intensidade')
plt.ylabel('Numero de Pixels')
plt.show()

# %%
edges = cv2.Canny(img_gray, 100, 200)

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(img_gray, cmap='gray')
plt.title('Imagem Original')
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(edges, cmap='gray')
plt.title('Segmentação por Bordas')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
sift = cv2.SIFT_create()
keypoints, descriptors = sift.detectAndCompute(img_gray, None)
img_sift = cv2.drawKeypoints(img_gray, keypoints, None, flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

plt.figure(figsize=(10,5))
plt.imshow(img_sift, cmap='gray')
plt.title('Pontos Chaves Detectados')
plt.axis('off')
plt.show()

# %%
blur_mean = cv2.blur(img, (5,5))
blur_gauss = cv2.GaussianBlur(img, (5,5), 0)

plt.figure(figsize=(20,6))

plt.subplot(1,3,1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Imagem Original')
plt.axis('off')

plt.subplot(1,3,2)
plt.imshow(cv2.cvtColor(blur_mean, cv2.COLOR_BGR2RGB))
plt.title('Suavização - Filtro de Media')
plt.axis('off')

plt.subplot(1,3,3)
plt.imshow(cv2.cvtColor(blur_gauss, cv2.COLOR_BGR2RGB))
plt.title('Suavização - Filtro Gaussiano')
plt.axis('off')

plt.show()
